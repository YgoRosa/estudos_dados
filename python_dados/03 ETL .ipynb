# %% [markdown]
# Carregando os dados

# %%
import json
import pandas as pd 
import logging
import requests

logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s - %(levelname)s - %(message)s"
)

logging.info("Iniciando...")

url = "https://pokeapi.co/api/v2/pokemon"

logging.info(f"Chamando API: {url}")

data = None

try: 
    r = requests.get(url)
    r.raise_for_status()
    data = r.json()
    logging.info("JSON recebido com sucesso!")

except requests.exceptions.HTTPError:
    logging.error("Erro HTTP! URL não encontrada")

except requests.exceptions.RequestException:
    logging.error("Erro na conexão")
# Out:
# 2025-12-08 16:33:03,110 - INFO - Iniciando...
# 2025-12-08 16:33:03,111 - INFO - Chamando API: https://pokeapi.co/api/v2/pokemon
# 2025-12-08 16:33:04,103 - INFO - JSON recebido com sucesso!

# %%
for p in data['results']:
    for i, s in enumerate(data["stats"]):
     print(i, s["stat"]["name"], s["base_stat"])
# Out:
# bulbasaur
# ivysaur
# venusaur
# charmander
# charmeleon
# charizard
# squirtle
# wartortle
# blastoise
# caterpie
# metapod
# butterfree
# weedle
# kakuna
# beedrill
# pidgey
# pidgeotto
# pidgeot
# rattata
# raticate
